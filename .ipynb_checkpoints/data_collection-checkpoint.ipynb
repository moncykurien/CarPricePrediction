# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\moncy\anaconda3\lib\site-packages (3.141.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: urllib3 in c:\users\moncy\anaconda3\lib\site-packages (from selenium) (1.26.4)

# %%
#selenium libraries
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import ElementNotInteractableException, ElementClickInterceptedException, TimeoutException
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import ui

import time as t
import pandas as pd
import re

from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains

# %%
import requests
import urllib.parse
import os
import shutil
pd.set_option("max_rows", None)

# %%
def get_drive_launch(url):
    """
    This function initiates the Chrome browser's driver with the url passed as a parameter and returns the driver instance.
    Parameters:
        url - url of the website
    return:
        driver - driver instance of the chrome browser    
    """
    #creating driver instance
    driver = webdriver.Chrome('./driver/chromedriver.exe')
    driver.maximize_window()
    
    #defining implicit wait
    driver.implicitly_wait(10)
    
    #launching the url
    driver.get(url)
    
    return driver

# %%
def scrape_cardata_olx():
    """
    This method will scrape cars data from the OLX site.
    """
    url = 'https://www.olx.in/cars_c84'
                            
    olx_brand = []
    olx_model = []
    olx_variant = []
    olx_manu_year = []
    olx_kilometers = []
    olx_fuel_type = []
    olx_owners = []
    olx_location = []
    olx_gear_type = []
    olx_price = []
    
    d = get_drive_launch(url)
    locations = d.find_elements_by_xpath("//div[@data-aut-id='collapsible_topLocations']//li//li")
    
    for i in range(len(locations)):
        try:
            locations[i].click()
        except StaleElementReferenceException:
            d.find_element_by_xpath("//a[@data-aut-id='location_India']//*[contains(text(),'India')]").click()
            t.sleep(3)
            if i < 4:
                locations = d.find_elements_by_xpath("//div[@data-aut-id='collapsible_topLocations']//li//li")
            else:
                locations = d.find_elements_by_xpath("//div[@data-aut-id='collapsible_topLocations']//li//ul/div/li")
            locations[i].click()
        except IndexError:
            break
        #print(d.find_element_by_xpath("//p[@id='adsResultsIn']/b").text)
        try:
            ol_location = d.find_element_by_xpath("//p[@id='adsResultsIn']/b").text
        except NoSuchElementException:
            continue
        gear_shifts = ['Automatic','Manual']            
        brands = d.find_elements_by_xpath("//*[contains(text(),'All Brands')]/following-sibling::div/div/div")
        
        for j in range(len(brands)):
            try:
                brands[j].click()
            except IndexError:
                break
            t.sleep(2)
            
            for gear in gear_shifts:
                try:
                    gear_ele = ui.WebDriverWait(d, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[contains(@class,'_2yv8x')]//*[contains(text(),'"+gear+"')]")))
                    gear_ele.click()
                except TimeoutException:
                    element = d.find_element_by_xpath("//div[contains(@class,'_2yv8x')]//*[contains(text(),'"+gear+"')]")
                    actions = ActionChains(d)
                    actions.move_to_element(element).perform()
                    #d.execute_script("window.scrollTo(0,document.body.scrollHeight)")
                    gear_ele = ui.WebDriverWait(d, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[contains(@class,'_2yv8x')]//*[contains(text(),'"+gear+"')]")))
                    gear_ele.click()
                    #d.find_element_by_xpath("//div[contains(@class,'_2yv8x')]//*[contains(text(),'"+gear+"')]").click()
                    
                t.sleep(2)
                cars = d.find_elements_by_xpath("//li[@data-aut-id='itemBox']")
                olx_gear_type.append(gear)
                
                for k in range(len(cars)):
                    
                    try:
                        cars[k].click()
                        t.sleep(2)    
                        try:
                            d.find_element_by_xpath("//*[contains(text(),'Oops')]")
                            d.get(url)
                            t.sleep(2)
                            cars = d.find_elements_by_xpath("//li[@data-aut-id='itemBox']")
                            continue
                        except NoSuchElementException:
                            pass
                        try:
                            brand = ui.WebDriverWait(d, 10).until(EC.presence_of_element_located((By.XPATH, "//div[@data-aut-id='breadcrumb']//li[7]")))
                            olx_brand.append(brand.text.split(' in ')[0].strip())
                            #olx_brand.append(d.find_element_by_xpath("//div[@data-aut-id='breadcrumb']//li[7]").text.split(' in ')[0].strip())
                        except NoSuchElementException:
                            t.sleep(2)
                            olx_brand.append(d.find_element_by_xpath("//span[@data-aut-id='value_make']").text)
                        #print(d.find_element_by_xpath("//div[@data-aut-id='breadcrumb']//li[7]").text.split(' in ')[0].strip())
                        except TimeoutException:
                            t.sleep(2)
                            try:
                                olx_brand.append(d.find_element_by_xpath("//div[@data-aut-id='breadcrumb']//li[4]").text)
                            except NoSuchElementException:
                                t.sleep(2)
                                olx_brand.append(d.find_element_by_xpath("//div[@data-aut-id='breadcrumb']//li[7]").text.split(' in ')[0].strip())
                            except NoSuchElementException:
                                t.sleep(2)
                                olx_brand.append(d.find_element_by_xpath("//span[@data-aut-id='value_make']").text)
                        
                        try:
                            model = ui.WebDriverWait(d, 10).until(EC.presence_of_element_located((By.XPATH, "//div[@data-aut-id='breadcrumb']//li[8]")))
                            olx_model.append(model.text.split(' in ')[0].strip())
                        except TimeoutException:
                            t.sleep(2)
                            olx_model.append(d.find_element_by_xpath("//div[@data-aut-id='breadcrumb']//li[4]").text.split(' in ')[0].strip())
                        
                        try:
                            olx_variant.append(d.find_element_by_xpath("//span[@data-aut-id='value_variant']").text)
                            olx_location.append(ol_location)
                        except NoSuchElementException:
                            try:
                                data = d.find_element_by_xpath("//div[@class='_1lysw']").text.split(' ',1)
                                olx_variant.append(data[0].split('-')[0])
                                olx_location.append(ol_location)
                            except NoSuchElementException:
                                olx_variant.append('--')
                                olx_location.append(ol_location)

                        try:
                            olx_manu_year.append(d.find_element_by_xpath("//span[@data-aut-id='value_year']").text)
                        except NoSuchElementException:
                            try:
                                data = d.find_element_by_xpath("//div[@class='_1lysw']").text.split(' ',1)
                                try:
                                    olx_manu_year.append(data[1])
                                except IndexError:
                                    olx_manu_year.append(d.find_element_by_xpath("//div[@data-aut-id='itemTitle']").text.split('(')[1].strip(')'))
                            except NoSuchElementException:
                                olx_manu_year.append('--')
                                
                        try:
                            olx_kilometers.append(d.find_element_by_xpath("//span[@data-aut-id='value_mileage']").text)
                        except NoSuchElementException:
                            try:
                                olx_kilometers.append(d.find_element_by_xpath("//div[contains(@class, '_1Rnja') and (contains(text(),'Km'))]").text)
                            except NoSuchElementException:
                                olx_kilometers.append('--')
                                
                        try:
                            olx_fuel_type.append(d.find_element_by_xpath("//span[@data-aut-id='value_petrol']").text)
                        except NoSuchElementException:
                            try:
                                olx_fuel_type.append(d.find_element_by_xpath("//div[contains(@class, '_1Rnja')]").text)
                            except NoSuchElementException:
                                olx_fuel_type.append('--')
                                
                        try:
                            olx_owners.append(d.find_element_by_xpath("//span[@data-aut-id='value_first_owner']").text)
                        except NoSuchElementException:
                            try:
                                olx_owners.append(d.find_element_by_xpath("//div[contains(@class, '_1z3tZ')]").text)
                            except NoSuchElementException:
                                olx_owners.append('--')
                        
                        try:
                            olx_price.append(d.find_element_by_xpath("//span[@data-aut-id='itemPrice']").text)
                        except NoSuchElementException:
                            try:
                                olx_price.append(d.find_element_by_xpath("//div[contains(@class, '_2r-aw')]").text)
                            except NoSuchElementException:
                                olx_price.append('--')
                                          
                        d.back()
                        t.sleep(2)
                        cars = d.find_elements_by_xpath("//li[@data-aut-id='itemBox']")
                    except ElementClickInterceptedException:
                        break            
            
            try:
                #exit_brand = ui.WebDriverWait(d, 10).until(EC.element_to_be_clickable((By.XPATH, "//a[@class='_19Q27']/div/div[not(contains(text(),'Automatic')) and not(contains(text(),'Manual'))]")))
                exit_brand = ui.WebDriverWait(d, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[@class='_2JV-T']//*[contains(text(),'Clear All')]")))
                exit_brand.click()
            except ElementClickInterceptedException:
                try:
                    exit_brand = ui.WebDriverWait(d, 10).until(EC.element_to_be_clickable((By.XPATH, "//a[@class='_19Q27']/div/div[not(contains(text(),'Automatic')) and not(contains(text(),'Manual'))]")))
                    exit_brand.click()
                except TimeoutException:
                    d.back()
                    t.sleep(2)
                    try:
                        exit_brand = d.find_element_by_xpath("//a[@class='_19Q27']/div/div[not(contains(text(),'Automatic')) and not(contains(text(),'Manual'))]")
                        exit_brand.click()
                    except (ElementClickInterceptedException, NoSuchElementException):
                        break
                except ElementClickInterceptedException:
                    d.get(url)
            except:
                break
                    
            t.sleep(2)
            brands = d.find_elements_by_xpath("//*[contains(text(),'All Brands')]/following-sibling::div/div/div")
        try:
            d.find_element_by_xpath("//*[contains(text(),'temporarily')]")
            d.get(url)
        except NoSuchElementException:
            pass
        t.sleep(2)
        try:
            d.find_element_by_xpath("//div[@data-aut-id='collapsible_topLocations']//*[contains(text(),'India')]").click()
        except (NoSuchElementException,ElementClickInterceptedException):
            d.get(url)
            
        t.sleep(2)
        if i < 4:
            locations = d.find_elements_by_xpath("//div[@data-aut-id='collapsible_topLocations']//li//li")
        else:
            locations = d.find_elements_by_xpath("//div[@data-aut-id='collapsible_topLocations']//li//ul/div/li")
    
    return (olx_brand,olx_model,olx_variant,olx_manu_year,olx_kilometers,olx_fuel_type,olx_owners,olx_location,olx_price)
    #return data

# %%
(olx_brand,olx_model,olx_variant,olx_manu_year,olx_kilometers,olx_fuel_type,olx_owners,olx_location,olx_price) = scrape_cardata_olx()
#data_frame = scrape_cardata_olx()

# %%
for i in (olx_brand,olx_model,olx_variant,olx_manu_year,olx_kilometers,olx_fuel_type,olx_owners,olx_location,olx_price):
    print(len(i))
# Out:
# 1164
# 1164
# 1164
# 1164
# 1164
# 1164
# 1164
# 1164
# 1164

# %%
data_frame = pd.DataFrame({'brand':olx_brand, 'model':olx_model, 'variant':olx_variant,
                        'manufactured_year':olx_manu_year, 'kilometers_driven':olx_kilometers,
                        'fuel_type':olx_fuel_type, 'owners':olx_owners, 'location':olx_location,
                        'price':olx_price})

# %%
data_frame.to_csv("olx_data.csv")

# %%
temp_url = "https://www.cardekho.com/used-cars+in+ahmedabad"
#https://www.cardekho.com/used-maruti+cars+in+ahmedabad
temp_url = temp_url.split('-')
temp_url.insert(1,"-maruthi+")
print("".join(temp_url))
# Out:
# https://www.cardekho.com/used-maruthi+cars+in+ahmedabad

# %%
len("mahindra renault".split())
# Out:
# 2

# %%
def scrape_cardata_cardekho():
    """
    This method will scrape cars data from the OLX site.
    """
    url = 'https://www.cardekho.com/usedCars'
                            
    cd_brand = []
    cd_model = []
    cd_variant = []
    cd_manu_year = []
    cd_kilometers = []
    cd_fuel_type = []
    cd_owners = []
    cd_location = []
    cd_price = []
    
    brand_name = ''
    model = ''
    variant = ''
    manu_year = ''
    kilometers = ''
    fuel_type = ''
    owners = ''
    location = ''
    price = ''
    
    
    
    d = get_drive_launch(url)
    
    locations = d.find_elements_by_xpath("//section[@data-track-component='Used cars in India by city']//li")
    lo = d.find_elements_by_xpath("//section[@data-track-component='Used cars in India by city']//li//span[3]")
    for i in range(len(locations)):
        try:
            location = lo[i].text.strip()
            locations[i].click()
            t.sleep(2)
            print("cars in ",location)
            temp_url = d.current_url
            #brands = d.find_elements_by_xpath("//ul[@data-track-section='Search by brand or model']//li[@class='accordion brandli makeList']/label")
            brand_names = d.find_elements_by_xpath("//ul[@data-track-section='Search by brand or model']//li[@class='accordion brandli makeList']/label")
            
            for j in range(len(brand_names)):
                try:
                    brand_name = brand_names[j].get_attribute('title')
                    if len(brand_name.split()) > 1:
                        brand = brand_name.split()
                        brand.insert(1,"-")
                        brand_name = "".join(brand)
                    tempurl = temp_url.split('-')
                    tempurl.insert(1,"-"+brand_name+"+")
                    tempurl = "".join(tempurl)
                    
                    d.get(tempurl)
                                        
                    t.sleep(2)
                    #print(d.find_element_by_xpath("//h1").text)
                                        
                    cars = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='imgarea hover']")
                    car_names = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='holder']//div[@class='gsc_col-xs-7 carsName']/a")
                    car_variants = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='holder']//div[@class='gsc_col-xs-7 carsName']/div[1]")
                    
                except Exception as e:
                    print("erroring out", e)
                    
                k = 0
                if len(cars) > 50:
                    cars = cars[11:50]
                for k in range(len(cars)):
                    try:
                        model = car_names[k].text.strip()
                        model = model.split(brand_name)
                        try:
                            manu_year = model[0].strip()
                        except:
                            manu_year = '--'
                        try:
                            model = model[1].strip()
                        except:
                            model = '--'
                        try:
                            variant = car_variants[k].text.strip()
                        except:
                            variant = '--'
                        cars[k].click()
                    except StaleElementReferenceException:
                        #d.get(d.current_url)
                        t.sleep(2)
                        cars = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='imgarea hover']")
                        car_names = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='holder']//div[@class='gsc_col-xs-7 carsName']/a")
                        car_variants = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='holder']//div[@class='gsc_col-xs-7 carsName']/div[1]")
                        model = car_names[k].text.strip()
                        model = model.split(brand_name)
                        try:
                            manu_year = model[0].strip()
                        except:
                            manu_year = '--'
                        try:
                            model = model[1].strip()
                        except:
                            model = '--'
                        try:
                            variant = car_variants[k].text.strip()
                        except:
                            variant = '--'
                        cars[k].click()
                    except IndexError:
                        break
                        
                    try:
                        kilometers = d.find_element_by_xpath("//div[contains(text(),'kms')]").text.strip()
                    except NoSuchElementException:
                        try:
                            kilometers = d.find_element_by_xpath("//*[contains(text(),'Kms')]").text.strip()
                        except NoSuchElementException:
                            kilometers = '--'
                    try:                        
                        owners = d.find_element_by_xpath("//*[contains(text(),'Owner')][2]").text.strip()
                    except NoSuchElementException:
                        try:
                            owners = d.find_element_by_xpath("//*[contains(text(),'Owner')]").text.strip()
                        except NoSuchElementException:
                            owners = '--'
                        
                    try:
                        fuel_type = d.find_element_by_xpath("//*[contains(text(),'Owner')]/ancestor::li/following-sibling::li[1]//div[@class='iconDetail']").text.strip()
                    except NoSuchElementException:
                        try:
                            fuel_type = d.find_element_by_xpath("//*[@src='https://stimg.cardekho.com/pwa/img/CDPrime/Fuel.svg']/../div").text.strip()
                        except NoSuchElementException:
                            try:
                                fuel_type = d.find_element_by_xpath("//*[contains(text(),'Fuel')]/following-sibling::div").text.strip()
                            except NoSuchElementException:
                                fuel_type = '--'
                    
                    try:
                        price = d.find_element_by_xpath("//div[@class='priceSection']/span[2]").text.strip()
                    except NoSuchElementException:
                        try:
                            price = d.find_element_by_xpath("//span[@class='amount']").text.strip()
                        except NoSuchElementException:
                            price = '--'
                    
                    cd_brand.append(brand_name)
                    cd_model.append(model)
                    cd_variant.append(variant)
                    cd_manu_year.append(manu_year)
                    cd_kilometers.append(kilometers)
                    cd_fuel_type.append(fuel_type)
                    cd_owners.append(owners)
                    cd_location.append(location)
                    cd_price.append(price)

                    d.back()
                    t.sleep(2)
                    cars = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='imgarea hover']")
                    car_names = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='holder']//div[@class='gsc_col-xs-7 carsName']/a")
                    car_variants = d.find_elements_by_xpath("//div[@class='gsc_col-md-4 gsc_col-sm-6 gsc_col-xs-12']//div[@class='holder']//div[@class='gsc_col-xs-7 carsName']/div[1]")
                    if len(cars) > 50:
                        cars = cars[11:50]
                
                
                brand_names = d.find_elements_by_xpath("//ul[@data-track-section='Search by brand or model']//li[@class='accordion brandli makeList']/label")
            
            t.sleep(2)
            d.get(url)
            t.sleep(2)
            locations = d.find_elements_by_xpath("//section[@data-track-component='Used cars in India by city']//li")
            lo = d.find_elements_by_xpath("//section[@data-track-component='Used cars in India by city']//li//span[3]")
            i += 1
        except (IndexError,ElementClickInterceptedException):
            d.get(url)
            t.sleep(2)
            locations = d.find_elements_by_xpath("//section[@data-track-component='Used cars in India by city']//li")
            lo = d.find_elements_by_xpath("//section[@data-track-component='Used cars in India by city']//li//span[3]")
            i += 1
    d.quit()
    return (cd_brand,cd_model,cd_variant,cd_manu_year,cd_kilometers,cd_fuel_type,cd_owners,cd_location,cd_price)
    #return data_frame

# %%
(cd_brand,cd_model,cd_variant,cd_manu_year,cd_kilometers,cd_fuel_type,cd_owners,cd_location,cd_price) = scrape_cardata_cardekho()
# Out:
# cars in  Ahmedabad
# cars in  Bangalore
# cars in  Chennai
# cars in  Delhi NCR
# cars in  Gurgaon
# cars in  Hyderabad
# cars in  Jaipur
# cars in  Kolkata
# cars in  Mumbai
# cars in  New Delhi
# cars in  Noida
# erroring out list index out of range
# erroring out list index out of range
# erroring out list index out of range
# erroring out list index out of range
# erroring out list index out of range
# erroring out list index out of range
# cars in  Pune

# %%
data_frame = pd.DataFrame({'brand':cd_brand, 'model':cd_model, 'variant':cd_variant,
                        'manufactured_year':cd_manu_year, 'kilometers_driven':cd_kilometers,
                        'fuel_type':cd_fuel_type, 'owners':cd_owners, 'location':cd_location,
                        'price':cd_price})
    
data_frame
# Out:
#                    brand                  model  \
# 0                 Maruti                   Eeco
# 1                 Maruti                 Baleno
# 2                 Maruti                   Eeco
# 3                 Maruti                Wagon R
# 4                 Maruti                Wagon R
# 5                 Maruti                Wagon R
# 6                 Maruti                Wagon R
# 7                 Maruti                 Baleno
# 8                 Maruti               S-Presso
# 9                 Maruti                   Eeco
# 10                Maruti            Swift Dzire
# 11                Maruti            Swift Dzire
# 12                Maruti                Wagon R
# 13                Maruti                  Swift
# 14                Maruti                   Ritz
# 15                Maruti                  Swift
# 16                Maruti                Wagon R
# 17                Maruti                  Swift
# 18                Maruti                Wagon R
# 19                Maruti            Swift Dzire
# 20               Hyundai              Grand i10
# 21               Hyundai              Grand i10
# 22               Hyundai                    EON
# 23               Hyundai              Grand i10
# 24               Hyundai                  Creta
# 25               Hyundai                  Verna
# 26               Hyundai              Grand i10
# 27               Hyundai                  Creta
# 28               Hyundai                  Creta
# 29               Hyundai                  Verna
# 30               Hyundai                  Creta
# 31               Hyundai                    i20
# 32               Hyundai              Grand i10
# 33               Hyundai                  Creta
# 34               Hyundai                    EON
# 35               Hyundai                  Xcent
# 36               Hyundai                    i20
# 37               Hyundai                    i10
# 38               Hyundai                    EON
# 39               Hyundai                  Verna
# 40                 Honda                   City
# 41                 Honda                   Brio
# 42                 Honda                   WR-V
# 43                 Honda                  Amaze
# 44                 Honda                   WR-V
# 45                 Honda                   Brio
# 46                 Honda                  Amaze
# 47                 Honda                   Brio
# 48                 Honda                  Amaze
# 49                 Honda                  Amaze
# 50                 Honda                 Accord
# 51                 Honda                  Amaze
# 52                 Honda                  Amaze
# 53                 Honda                  Amaze
# 54                 Honda                   Jazz
# 55                 Honda                   Jazz
# 56                 Honda                   City
# 57                 Honda                   Brio
# 58                 Honda                  Amaze
# 59                Toyota                 Innova
# 60                Toyota             Etios Liva
# 61                Toyota                  Yaris
# 62                Toyota          Corolla Altis
# 63                Toyota             Etios Liva
# 64                Toyota          Innova Crysta
# 65                Toyota          Corolla Altis
# 66                Toyota                 Innova
# 67                Toyota          Innova Crysta
# 68                Toyota                 Innova
# 69                Toyota               Fortuner
# 70                Toyota          Innova Crysta
# 71                Toyota               Fortuner
# 72                Toyota          Innova Crysta
# 73                Toyota                 Innova
# 74                Toyota                 Innova
# 75                Toyota          Innova Crysta
# 76                Toyota          Innova Crysta
# 77                Toyota                  Etios
# 78                Toyota               Fortuner
# 79              Mahindra                 XUV500
# 80              Mahindra                Marazzo
# 81              Mahindra                Scorpio
# 82              Mahindra                   Xylo
# 83              Mahindra                 XUV500
# 84              Mahindra                 Quanto
# 85              Mahindra                 Bolero
# 86              Mahindra                TUV 300
# 87              Mahindra                 XUV500
# 88              Mahindra                   Thar
# 89              Mahindra                 XUV500
# 90              Mahindra                   Thar
# 91              Mahindra                 XUV500
# 92              Mahindra                 XUV500
# 93              Mahindra                 XUV500
# 94              Mahindra                 Bolero
# 95              Mahindra                 XUV500
# 96              Mahindra                 XUV500
# 97              Mahindra                Marazzo
# 98              Mahindra                Marazzo
# 99                  Ford               Ecosport
# 100                 Ford            Figo Aspire
# 101                 Ford              Endeavour
# 102                 Ford                   Figo
# 103                 Ford               Ecosport
# 104                 Ford                   Figo
# 105                 Ford               Ecosport
# 106                 Ford                   Figo
# 107                 Ford               Ecosport
# 108                 Ford                   Figo
# 109                 Ford              Endeavour
# 110                 Ford               Ecosport
# 111                 Ford               Ecosport
# 112                 Ford              Endeavour
# 113                 Ford               Ecosport
# 114                 Ford              Endeavour
# 115                 Ford               Ecosport
# 116                 Ford               Ecosport
# 117                 Ford               Ecosport
# 118                 Ford                   Figo
# 119           Volkswagen                  Vento
# 120           Volkswagen                   Ameo
# 121           Volkswagen                  Vento
# 122           Volkswagen                  Vento
# 123           Volkswagen                 Passat
# 124           Volkswagen                   Polo
# 125           Volkswagen                  Vento
# 126           Volkswagen                   Polo
# 127           Volkswagen                  Vento
# 128           Volkswagen                  Vento
# 129           Volkswagen                   Ameo
# 130           Volkswagen                   Polo
# 131           Volkswagen                 Passat
# 132           Volkswagen                  Vento
# 133           Volkswagen                 Passat
# 134           Volkswagen                   Polo
# 135           Volkswagen                   Polo
# 136           Volkswagen                  Vento
# 137           Volkswagen                  Jetta
# 138           Volkswagen                  Vento
# 139                 Tata                   Hexa
# 140                 Tata                  Nexon
# 141                 Tata           Indica Vista
# 142                 Tata                  Nexon
# 143                 Tata                   Zest
# 144                 Tata                   Nano
# 145                 Tata                  Tiago
# 146                 Tata                  Nexon
# 147                 Tata                  Manza
# 148                 Tata          Safari Storme
# 149                 Tata                   Nano
# 150                 Tata                 Indigo
# 151                 Tata                   Nano
# 152                 Tata           Indica Vista
# 153                 Tata           Indica Vista
# 154                 Tata                   Sumo
# 155                 Tata                 Indigo
# 156                 Tata                 Indigo
# 157                 Tata                 Indica
# 158                 Tata          Safari Storme
# 159        Mercedes-Benz                B Class
# 160        Mercedes-Benz                E-Class
# 161        Mercedes-Benz                E-Class
# 162        Mercedes-Benz                E-Class
# 163        Mercedes-Benz                E-Class
# 164        Mercedes-Benz            New C-Class
# 165        Mercedes-Benz            New C-Class
# 166        Mercedes-Benz                B Class
# 167        Mercedes-Benz            New C-Class
# 168        Mercedes-Benz              GLA Class
# 169        Mercedes-Benz                E-Class
# 170        Mercedes-Benz                B Class
# 171        Mercedes-Benz              GLA Class
# 172        Mercedes-Benz              GLA Class
# 173        Mercedes-Benz                E-Class
# 174        Mercedes-Benz              GLA Class
# 175        Mercedes-Benz                    GLC
# 176        Mercedes-Benz                A Class
# 177        Mercedes-Benz            New C-Class
# 178        Mercedes-Benz                S-Class
# 179              Renault                  Lodgy
# 180              Renault                 Duster
# 181              Renault                  Pulse
# 182              Renault                 Duster
# 183              Renault                 Captur
# 184              Renault                   KWID
# 185              Renault                   KWID
# 186              Renault                 Duster
# 187              Renault                 Duster
# 188              Renault                 Duster
# 189              Renault                 Duster
# 190              Renault                  Scala
# 191              Renault                 Duster
# 192              Renault                   KWID
# 193              Renault                   KWID
# 194              Renault                   KWID
# 195              Renault                  Scala
# 196              Renault                  Scala
# 197              Renault                  Lodgy
# 198              Renault                   KWID
# 199                  BMW                     X1
# 200                  BMW               3 Series
# 201                  BMW               5 Series
# 202                  BMW               5 Series
# 203                  BMW            3 Series GT
# 204                  BMW               5 Series
# 205                  BMW               5 Series
# 206                  BMW               3 Series
# 207                  BMW                     X3
# 208                  BMW                     X3
# 209                  BMW               5 Series
# 210                  BMW               7 Series
# 211                  BMW               3 Series
# 212                  BMW                     X1
# 213                  BMW               5 Series
# 214                  BMW            3 Series GT
# 215                  BMW               5 Series
# 216                  BMW               5 Series
# 217                  BMW               3 Series
# 218                  BMW               3 Series
# 219            Chevrolet                  Enjoy
# 220            Chevrolet                  Enjoy
# 221            Chevrolet                  Enjoy
# 222            Chevrolet                  Cruze
# 223            Chevrolet                 Tavera
# 224            Chevrolet                 Tavera
# 225            Chevrolet                 Tavera
# 226            Chevrolet                  Cruze
# 227            Chevrolet                  Enjoy
# 228            Chevrolet                 Tavera
# 229            Chevrolet                  Spark
# 230            Chevrolet                   Beat
# 231            Chevrolet                  Spark
# 232            Chevrolet                  Spark
# 233            Chevrolet                  Spark
# 234            Chevrolet                  Spark
# 235            Chevrolet                   Beat
# 236            Chevrolet                  Cruze
# 237            Chevrolet                   Beat
# 238            Chevrolet                  Spark
# 239                 Audi                     A4
# 240                 Audi                     Q7
# 241                 Audi                     Q7
# 242                 Audi                     Q7
# 243                 Audi                     A4
# 244                 Audi                     A4
# 245                 Audi                     Q7
# 246                 Audi                     Q3
# 247                 Audi                     A4
# 248                 Audi                     Q5
# 249                 Audi                     A6
# 250                 Audi                     A4
# 251                 Audi                     Q3
# 252                 Audi                     A3
# 253                 Audi                     Q5
# 254                 Audi                     A4
# 255                 Audi                     A4
# 256                 Audi                     Q3
# 257                 Audi                     A4
# 258               Nissan                Terrano
# 259               Nissan                 Evalia
# 260               Nissan                Terrano
# 261               Nissan                  Sunny
# 262               Nissan                  Micra
# 263               Nissan                  Micra
# 264               Nissan                  Sunny
# 265               Nissan                  Micra
# 266               Nissan                  Micra
# 267               Nissan                  Micra
# 268               Nissan                X-Trail
# 269               Nissan                Terrano
# 270               Nissan                  Sunny
# 271               Nissan                Terrano
# 272               Nissan                  Micra
# 273               Nissan                  Micra
# 274               Nissan                  Micra
# 275               Nissan                  Sunny
# 276               Nissan                Terrano
# 277               Nissan                  Micra
# 278                Skoda                  Rapid
# 279                Skoda                 Kodiaq
# 280                Skoda                  Laura
# 281                Skoda                 Kodiaq
# 282                Skoda                  Rapid
# 283                Skoda                  Rapid
# 284                Skoda                 Kodiaq
# 285                Skoda                Octavia
# 286                Skoda                  Rapid
# 287                Skoda                Octavia
# 288                Skoda                 Superb
# 289                Skoda                Octavia
# 290                Skoda                  Fabia
# 291               Datsun                 RediGO
# 292               Datsun                     GO
# 293               Datsun                 RediGO
# 294               Datsun                 RediGO
# 295               Datsun                     GO
# 296               Datsun                 RediGO
# 297               Datsun                GO Plus
# 298               Datsun                     GO
# 299               Datsun                GO Plus
# 300               Datsun                 RediGO
# 301               Datsun                 RediGO
# 302               Datsun                     GO
# 303                Volvo      S60 Cross Country
# 304                Volvo                  XC 90
# 305                Volvo                    S60
# 306                Volvo                   XC40
# 307                Volvo                    S60
# 308                Volvo                    V40
# 309                Volvo                    S60
# 310                Volvo                  XC 90
# 311                Volvo                   XC60
# 312                 Fiat           Grande Punto
# 313                 Fiat           Grande Punto
# 314                 Fiat           Grande Punto
# 315                 Fiat           Grande Punto
# 316                 Fiat                  Linea
# 317                 Fiat           Grande Punto
# 318                 Fiat           Grande Punto
# 319                 Fiat                  Linea
# 320                 Jeep                Compass
# 321                 Jeep                Compass
# 322                 Jeep                Compass
# 323                 Jeep                Compass
# 324                 Jeep                Compass
# 325                  Kia                 Seltos
# 326                  Kia                 Seltos
# 327                  Kia                 Seltos
# 328                  Kia                 Seltos
# 329                  Kia                 Seltos
# 330   Mahindra-Ssangyong                     --
# 331   Mahindra-Ssangyong                     --
# 332   Mahindra-Ssangyong                     --
# 333   Mahindra-Ssangyong                     --
# 334                   MG                 Hector
# 335                   MG                 Hector
# 336                   MG                 Hector
# 337                   MG                 Hector
# 338           Mitsubishi                 Pajero
# 339           Mitsubishi                 Pajero
# 340           Mitsubishi              Outlander
# 341              Porsche                Cayenne
# 342              Porsche                Cayenne
# 343              Porsche                Cayenne
# 344           Land-Rover                     --
# 345           Land-Rover                     --
# 346           Land-Rover                     --
# 347               Jaguar                     XF
# 348               Jaguar                 F-Pace
# 349                 Mini                 Cooper
# 350                 Mini                 Cooper
# 351     Mahindra-Renault                     --
# 352               Maruti                 Baleno
# 353               Maruti                 Baleno
# 354               Maruti                 Baleno
# 355               Maruti                Celerio
# 356               Maruti                 Baleno
# 357               Maruti                 Baleno
# 358               Maruti                 Baleno
# 359               Maruti                 Baleno
# 360               Maruti                   Alto
# 361               Maruti                 Baleno
# 362               Maruti                   Alto
# 363               Maruti               Alto 800
# 364               Maruti               Alto 800
# 365               Maruti                Celerio
# 366               Maruti                Wagon R
# 367               Maruti                Wagon R
# 368               Maruti               Alto 800
# 369               Maruti               Alto 800
# 370               Maruti                  Ignis
# 371               Maruti                   Alto
# 372              Hyundai                 Santro
# 373              Hyundai              Grand i10
# 374              Hyundai              Grand i10
# 375              Hyundai              Grand i10
# 376              Hyundai              Grand i10
# 377              Hyundai             i20 Active
# 378              Hyundai              Grand i10
# 379              Hyundai              Grand i10
# 380              Hyundai              Grand i10
# 381              Hyundai                    EON
# 382              Hyundai              Grand i10
# 383              Hyundai              Grand i10
# 384              Hyundai              Grand i10
# 385              Hyundai             i20 Active
# 386              Hyundai              Grand i10
# 387              Hyundai                    i10
# 388              Hyundai                    i10
# 389              Hyundai                    i10
# 390              Hyundai              Grand i10
# 391              Hyundai                    i10
# 392                Honda                   Jazz
# 393                Honda                   Jazz
# 394                Honda                   Jazz
# 395                Honda                   Jazz
# 396                Honda                   Jazz
# 397                Honda                   Jazz
# 398                Honda                   Brio
# 399                Honda                   Jazz
# 400                Honda                   City
# 401                Honda                   Jazz
# 402                Honda                  Amaze
# 403                Honda                  Amaze
# 404                Honda                   Brio
# 405                Honda                   City
# 406                Honda                   Jazz
# 407                Honda                   City
# 408                Honda                   City
# 409                Honda                   City
# 410                Honda                   Brio
# 411               Toyota             Etios Liva
# 412               Toyota                  Yaris
# 413               Toyota          Innova Crysta
# 414               Toyota                  Camry
# 415               Toyota               Fortuner
# 416               Toyota             Etios Liva
# 417               Toyota                 Innova
# 418               Toyota                 Innova
# 419               Toyota                 Innova
# 420               Toyota                Corolla
# 421               Toyota             Etios Liva
# 422               Toyota             Etios Liva
# 423               Toyota          Innova Crysta
# 424               Toyota                  Etios
# 425               Toyota                 Innova
# 426               Toyota           Land Cruiser
# 427               Toyota               Fortuner
# 428               Toyota           Land Cruiser
# 429               Toyota                  Yaris
# 430               Toyota                 Innova
# 431             Mahindra                TUV 300
# 432             Mahindra                Scorpio
# 433             Mahindra                Scorpio
# 434             Mahindra                TUV 300
# 435             Mahindra                   Xylo
# 436             Mahindra                KUV 100
# 437             Mahindra                 XUV500
# 438             Mahindra                   Xylo
# 439             Mahindra                 XUV500
# 440             Mahindra                   Thar
# 441             Mahindra                Scorpio
# 442             Mahindra                 XUV500
# 443             Mahindra                   Xylo
# 444             Mahindra                 XUV500
# 445             Mahindra                 XUV500
# 446             Mahindra                 XUV500
# 447             Mahindra                 XUV500
# 448             Mahindra                 XUV500
# 449             Mahindra                Scorpio
# 450             Mahindra                KUV 100
# 451                 Ford         Fiesta Classic
# 452                 Ford                   Figo
# 453                 Ford               Ecosport
# 454                 Ford               Ecosport
# 455                 Ford                Classic
# 456                 Ford              Endeavour
# 457                 Ford                   Figo
# 458                 Ford                   Figo
# 459                 Ford               EcoSport
# 460                 Ford                   Figo
# 461                 Ford               Ecosport
# 462                 Ford                 Fiesta
# 463                 Ford               EcoSport
# 464                 Ford                   Figo
# 465                 Ford                   Figo
# 466                 Ford                   Figo
# 467                 Ford            Figo Aspire
# 468                 Ford              Endeavour
# 469                 Ford              Endeavour
# 470                 Ford              Endeavour
# 471           Volkswagen                  Vento
# 472           Volkswagen                   Polo
# 473           Volkswagen                   Ameo
# 474           Volkswagen        Tiguan Allspace
# 475           Volkswagen                  Vento
# 476           Volkswagen                  Vento
# 477           Volkswagen                  Vento
# 478           Volkswagen                   Polo
# 479           Volkswagen                  Vento
# 480           Volkswagen                   Polo
# 481           Volkswagen                   Polo
# 482           Volkswagen                   Polo
# 483           Volkswagen                   Polo
# 484           Volkswagen                   Polo
# 485           Volkswagen                   Polo
# 486           Volkswagen                   Polo
# 487           Volkswagen                   Polo
# 488           Volkswagen                 Passat
# 489           Volkswagen                   Polo
# 490           Volkswagen                 Beetle
# 491        Mercedes-Benz                E-Class
# 492        Mercedes-Benz                    GLC
# 493        Mercedes-Benz                M-Class
# 494        Mercedes-Benz                    CLA
# 495        Mercedes-Benz                    CLA
# 496        Mercedes-Benz                    CLA
# 497        Mercedes-Benz                M-Class
# 498        Mercedes-Benz            New C-Class
# 499        Mercedes-Benz                E-Class
# 500        Mercedes-Benz                B Class
# 501        Mercedes-Benz               GL-Class
# 502        Mercedes-Benz            New C-Class
# 503        Mercedes-Benz               GL-Class
# 504        Mercedes-Benz                E-Class
# 505        Mercedes-Benz              GLE Class
# 506        Mercedes-Benz              GLE Class
# 507        Mercedes-Benz                    CLA
# 508        Mercedes-Benz              GLE Class
# 509        Mercedes-Benz                M-Class
# 510        Mercedes-Benz              GLA Class
# 511                  BMW               7 Series
# 512                  BMW               7 Series
# 513                  BMW               3 Series
# 514                  BMW               5 Series
# 515                  BMW               6 Series
# 516                  BMW               3 Series
# 517                  BMW               5 Series
# 518                  BMW                     X1
# 519                  BMW               1 Series
# 520                  BMW               5 Series
# 521                  BMW                     X5
# 522                  BMW               5 Series
# 523                  BMW               5 Series
# 524                  BMW               5 Series
# 525                  BMW               3 Series
# 526                  BMW               5 Series
# 527                  BMW                     X1
# 528                  BMW               5 Series
# 529                  BMW                     Z4
# 530                  BMW                     X3
# 531              Renault                   KWID
# 532              Renault                   KWID
# 533              Renault                   KWID
# 534              Renault                   KWID
# 535              Renault                   KWID
# 536              Renault                   KWID
# 537              Renault                   KWID
# 538              Renault                   KWID
# 539              Renault                   KWID
# 540              Renault                   KWID
# 541              Renault                   KWID
# 542              Renault                 Duster
# 543              Renault                   KWID
# 544              Renault                   KWID
# 545              Renault                   KWID
# 546              Renault                   KWID
# 547              Renault                   KWID
# 548              Renault                 Duster
# 549              Renault                   KWID
# 550              Renault                  Lodgy
# 551                 Tata                  Tigor
# 552                 Tata                  Tiago
# 553                 Tata                  Tiago
# 554                 Tata                   Nano
# 555                 Tata                   Nano
# 556                 Tata                 Indigo
# 557                 Tata                Harrier
# 558                 Tata                Harrier
# 559                 Tata             New Safari
# 560                 Tata          Safari Storme
# 561                 Tata                  Manza
# 562                 Tata             New Safari
# 563                 Tata                   Nano
# 564                 Tata                  Tiago
# 565                 Tata                  Tiago
# 566                 Tata                  Tiago
# 567                 Tata                   Nano
# 568                 Tata                  Manza
# 569                 Tata                   Nano
# 570                 Tata                   Sumo
# 571                 Audi                     Q7
# 572                 Audi                     Q5
# 573                 Audi                     Q3
# 574                 Audi                     A6
# 575                 Audi                     TT
# 576                 Audi                     Q5
# 577                 Audi                     Q5
# 578                 Audi                     Q5
# 579                 Audi                     Q3
# 580                 Audi                     Q5
# 581                 Audi                     Q5
# 582                 Audi                     A4
# 583                 Audi                     A6
# 584                 Audi                     Q7
# 585                 Audi                     A3
# 586                 Audi                     Q5
# 587                 Audi                     A4
# 588                 Audi                     Q7
# 589                 Audi                     A6
# 590                 Audi                     Q3
# 591                Skoda                  Rapid
# 592                Skoda                Octavia
# 593                Skoda                 Superb
# 594                Skoda                  Rapid
# 595                Skoda                 Superb
# 596                Skoda                Octavia
# 597                Skoda                  Rapid
# 598                Skoda                  Rapid
# 599                Skoda                  Rapid
# 600                Skoda                  Rapid
# 601                Skoda                  Rapid
# 602                Skoda                  Fabia
# 603                Skoda                  Rapid
# 604                Skoda                Octavia
# 605                Skoda                  Laura
# 606                Skoda                Octavia
# 607                Skoda                  Rapid
# 608                Skoda                  Rapid
# 609                Skoda                  Rapid
# 610                Skoda                Octavia
# 611            Chevrolet                  Spark
# 612            Chevrolet                 Tavera
# 613            Chevrolet         Sail Hatchback
# 614            Chevrolet           Optra Magnum
# 615            Chevrolet                   Beat
# 616            Chevrolet                   Sail
# 617            Chevrolet                 Tavera
# 618            Chevrolet                   Beat
# 619            Chevrolet                 Tavera
# 620            Chevrolet                   Beat
# 621            Chevrolet                  Cruze
# 622            Chevrolet                Captiva
# 623            Chevrolet                   Beat
# 624            Chevrolet                   Beat
# 625            Chevrolet                   Beat
# 626            Chevrolet                   Beat
# 627            Chevrolet                   Beat
# 628            Chevrolet         Sail Hatchback
# 629            Chevrolet                  Spark
# 630            Chevrolet                 Tavera
# 631                 Fiat              Avventura
# 632                 Fiat                    500
# 633                 Fiat                  Linea
# 634                 Fiat           Grande Punto
# 635                 Fiat                  Linea
# 636                 Fiat                  Linea
# 637                 Fiat                  Linea
# 638                 Fiat           Grande Punto
# 639                 Fiat           Grande Punto
# 640                 Fiat                  Petra
# 641                 Fiat           Grande Punto
# 642                 Fiat           Grande Punto
# 643                 Fiat           Grande Punto
# 644                Volvo                  XC 90
# 645                Volvo                    V40
# 646                Volvo                  XC 90
# 647                Volvo                    S60
# 648                Volvo                   S 80
# 649                Volvo                    V40
# 650                Volvo                   XC60
# 651                Volvo                    S60
# 652                Volvo                    S90
# 653                Volvo                    V40
# 654                Volvo                   XC60
# 655           Land-Rover                     --
# 656           Land-Rover                     --
# 657           Land-Rover                     --
# 658           Land-Rover                     --
# 659           Land-Rover                     --
# 660           Land-Rover                     --
# 661           Land-Rover                     --
# 662           Land-Rover                     --
# 663           Land-Rover                     --
# 664           Land-Rover                     --
# 665           Land-Rover                     --
# 666               Nissan                Terrano
# 667               Nissan                  Micra
# 668               Nissan           Micra Active
# 669               Nissan                Terrano
# 670               Nissan                  Micra
# 671               Nissan                  Micra
# 672               Nissan                  Micra
# 673               Nissan                  Micra
# 674               Nissan                  Micra
# 675               Nissan                Terrano
# 676               Jaguar                     XF
# 677               Jaguar                     XF
# 678               Jaguar                     XF
# 679               Jaguar                     XF
# 680               Jaguar                 F-Pace
# 681               Jaguar                 F-Pace
# 682               Jaguar                     XF
# 683               Jaguar                     XF
# 684               Jaguar                     XJ
# 685           Mitsubishi                  Cedia
# 686           Mitsubishi                  Cedia
# 687           Mitsubishi                 Pajero
# 688           Mitsubishi                  Cedia
# 689           Mitsubishi                  Cedia
# 690           Mitsubishi                  Cedia
# 691           Mitsubishi                 Lancer
# 692           Mitsubishi                 Pajero
# 693           Mitsubishi                 Pajero
# 694                 Jeep                Compass
# 695                 Jeep                Compass
# 696                 Jeep                Compass
# 697                 Jeep                Compass
# 698                 Jeep                Compass
# 699                 Jeep                Compass
# 700                 Jeep                Compass
# 701                 Jeep                Compass
# 702                 Jeep                Compass
# 703               Datsun                 RediGO
# 704               Datsun                     GO
# 705               Datsun                 RediGO
# 706               Datsun                 RediGO
# 707               Datsun                     GO
# 708               Datsun                     GO
# 709               Datsun                     GO
# 710              Porsche                Cayenne
# 711              Porsche               Panamera
# 712              Porsche               Panamera
# 713              Porsche               Panamera
# 714              Porsche                Cayenne
# 715              Porsche                 Cayman
# 716                  Kia                 Seltos
# 717                  Kia                  Sonet
# 718                  Kia                  Sonet
# 719                  Kia                 Seltos
# 720                  Kia                  Sonet
# 721                  Kia                 Seltos
# 722   Mahindra-Ssangyong                     --
# 723   Mahindra-Ssangyong                     --
# 724   Mahindra-Ssangyong                     --
# 725   Mahindra-Ssangyong                     --
# 726                   MG                 Hector
# 727                   MG                 Hector
# 728                   MG                 Hector
# 729                   MG                 Hector
# 730                 Mini                 3 DOOR
# 731                 Mini      Cooper Countryman
# 732                Lexus                     NX
# 733              Premier                    Rio
# 734               Maruti               Alto K10
# 735               Maruti                 Baleno
# 736               Maruti               S-Presso
# 737               Maruti                 Baleno
# 738               Maruti                 Baleno
# 739               Maruti                 Baleno
# 740               Maruti                Celerio
# 741               Maruti                   Ciaz
# 742               Maruti                 Baleno
# 743               Maruti                 Baleno
# 744               Maruti                 Baleno
# 745               Maruti               S-Presso
# 746               Maruti                   Ciaz
# 747               Maruti                   Ciaz
# 748               Maruti                   Ciaz
# 749               Maruti                 Baleno
# 750               Maruti                 Baleno
# 751               Maruti               Alto K10
# 752               Maruti               Alto K10
# 753               Maruti                   Ciaz
# 754              Hyundai              Grand i10
# 755              Hyundai              Grand i10
# 756              Hyundai                 Santro
# 757              Hyundai              Grand i10
# 758              Hyundai              Grand i10
# 759              Hyundai              Grand i10
# 760              Hyundai              Grand i10
# 761              Hyundai                    i20
# 762              Hyundai                  Venue
# 763              Hyundai                    i20
# 764              Hyundai                    i20
# 765              Hyundai              Grand i10
# 766              Hyundai                  Xcent
# 767              Hyundai                  Xcent
# 768              Hyundai                  Xcent
# 769              Hyundai                    EON
# 770              Hyundai                    EON
# 771              Hyundai                    EON
# 772              Hyundai                    i20
# 773              Hyundai                  Verna
# 774                Honda                   Brio
# 775                Honda                   Brio
# 776                Honda                   Brio
# 777                Honda                   Brio
# 778                Honda                   Jazz
# 779                Honda                   Brio
# 780                Honda                   Brio
# 781                Honda                  Civic
# 782                Honda                   City
# 783                Honda                   City
# 784                Honda                   City
# 785                Honda                   City
# 786                Honda                   City
# 787                Honda                   Jazz
# 788                Honda                   Brio
# 789                Honda                  Civic
# 790                Honda                   City
# 791                Honda                   City
# 792               Toyota          Corolla Altis
# 793               Toyota          Corolla Altis
# 794               Toyota                 Innova
# 795               Toyota                 Innova
# 796               Toyota          Innova Crysta
# 797               Toyota                 Innova
# 798               Toyota                 Innova
# 799               Toyota                 Innova
# 800               Toyota                 Innova
# 801               Toyota          Innova Crysta
# 802               Toyota                  Yaris
# 803               Toyota                Corolla
# 804               Toyota               Fortuner
# 805               Toyota               Fortuner
# 806               Toyota          Corolla Altis
# 807               Toyota             Etios Liva
# 808               Toyota               Fortuner
# 809               Toyota               Fortuner
# 810               Toyota               Fortuner
# 811               Toyota          Innova Crysta
# 812           Volkswagen                   Polo
# 813           Volkswagen                   Ameo
# 814           Volkswagen                  Vento
# 815           Volkswagen                   Polo
# 816           Volkswagen                   Polo
# 817           Volkswagen                  Vento
# 818           Volkswagen                  Vento
# 819           Volkswagen                   Polo
# 820           Volkswagen                  Vento
# 821           Volkswagen                  Vento
# 822           Volkswagen                   Polo
# 823           Volkswagen                  Vento
# 824           Volkswagen                  Vento
# 825           Volkswagen                  Vento
# 826           Volkswagen                  Vento
# 827           Volkswagen                   Polo
# 828           Volkswagen                   Polo
# 829           Volkswagen                   Polo
# 830           Volkswagen                  Jetta
# 831           Volkswagen                   Polo
# 832                 Audi                     A6
# 833                 Audi                     Q3
# 834                 Audi                     A4
# 835                 Audi                     Q7
# 836                 Audi                     Q8
# 837                 Audi                     Q8
# 838                 Audi                     A6
# 839                 Audi                     A4
# 840                 Audi                     A6
# 841                 Audi                     A3
# 842                 Audi                     S5
# 843                 Audi                     Q3
# 844                 Audi                     Q3
# 845                 Audi                     Q7
# 846                 Audi                     A6
# 847                 Audi                     A3
# 848                 Audi                     A6
# 849                 Audi                     A3
# 850                 Audi                     A3
# 851                 Audi                     A6
# 852              Renault                   KWID
# 853              Renault                 Triber
# 854              Renault                   KWID
# 855              Renault                   KWID
# 856              Renault                 Triber
# 857              Renault                 Duster
# 858              Renault                   KWID
# 859              Renault                 Duster
# 860              Renault                 Duster
# 861              Renault                 Duster
# 862              Renault                   KWID
# 863              Renault                   KWID
# 864              Renault                   KWID
# 865              Renault                  Kiger
# 866              Renault                   KWID
# 867              Renault                  Pulse
# 868              Renault                 Duster
# 869              Renault                   KWID
# 870                 Ford            Figo Aspire
# 871                 Ford               Ecosport
# 872                 Ford                   Figo
# 873                 Ford              Endeavour
# 874                 Ford              Endeavour
# 875                 Ford               Ecosport
# 876                 Ford               EcoSport
# 877                 Ford               Ecosport
# 878                 Ford               EcoSport
# 879                 Ford                   Figo
# 880                 Ford              Endeavour
# 881                 Ford               Ecosport
# 882                 Ford                   Figo
# 883                 Ford                   Figo
# 884                 Ford               EcoSport
# 885                 Ford              Endeavour
# 886                 Ford               Ecosport
# 887             Mahindra                 XUV500
# 888             Mahindra                TUV 300
# 889             Mahindra                Scorpio
# 890             Mahindra                 XUV500
# 891             Mahindra                Scorpio
# 892             Mahindra                   Thar
# 893             Mahindra                Marazzo
# 894             Mahindra                KUV 100
# 895             Mahindra                 Quanto
# 896             Mahindra                KUV 100
# 897             Mahindra                Scorpio
# 898             Mahindra                 Bolero
# 899             Mahindra                Scorpio
# 900             Mahindra                Scorpio
# 901             Mahindra                 XUV500
# 902             Mahindra                Scorpio
# 903             Mahindra                 XUV500
# 904             Mahindra                   Thar
# 905                  BMW                     X1
# 906                  BMW               5 Series
# 907                  BMW               3 Series
# 908                  BMW               7 Series
# 909                  BMW            3 Series GT
# 910                  BMW               3 Series
# 911                  BMW                     X3
# 912                  BMW                     X1
# 913                  BMW               3 Series
# 914                  BMW               5 Series
# 915                  BMW                     X1
# 916                  BMW                     X1
# 917                 Tata                  Tigor
# 918                 Tata                  Nexon
# 919                 Tata                   Nano
# 920                 Tata                   Zest
# 921                 Tata                Harrier
# 922                 Tata                  Tiago
# 923                 Tata                   Zest
# 924                 Tata             New Safari
# 925                 Tata          Safari Storme
# 926                 Tata          Safari Storme
# 927                 Tata                  Tiago
# 928               Nissan                  Sunny
# 929               Nissan                Terrano
# 930               Nissan                Terrano
# 931               Nissan                Terrano
# 932               Nissan                  Sunny
# 933               Nissan                  Sunny
# 934               Nissan                  Sunny
# 935               Nissan                  Terra
# 936               Nissan                Terrano
# 937               Nissan                  Kicks
# 938        Mercedes-Benz              CLS-Class
# 939        Mercedes-Benz                    CLA
# ...
# 2229          Second Owner     Mumbai   23.5 Lakh*
# 2230           First Owner     Mumbai  35.76 Lakh*
# 2231           First Owner     Mumbai  34.99 Lakh*
# 2232           First Owner     Mumbai  37.99 Lakh*
# 2233           First Owner     Mumbai  33.99 Lakh*
# 2234           First Owner     Mumbai   76.5 Lakh*
# 2235          Second Owner     Mumbai     34 Lakh*
# 2236           First Owner     Mumbai  45.99 Lakh*
# 2237           First Owner     Mumbai     23 Lakh*
# 2238          Second Owner     Mumbai   14.5 Lakh*
# 2239           Third Owner     Mumbai   9.75 Lakh*
# 2240           First Owner     Mumbai  22.75 Lakh*
# 2241           First Owner     Mumbai  74.75 Lakh*
# 2242           First Owner     Mumbai  18.85 Lakh*
# 2243           First Owner     Mumbai  18.75 Lakh*
# 2244           First Owner     Mumbai  17.99 Lakh*
# 2245           First Owner     Mumbai  18.99 Lakh*
# 2246           First Owner     Mumbai  17.11 Lakh*
# 2247           First Owner     Mumbai  11.99 Lakh*
# 2248           First Owner     Mumbai  17.11 Lakh*
# 2249           First Owner     Mumbai  17.85 Lakh*
# 2250           First Owner     Mumbai  18.85 Lakh*
# 2251           First Owner     Mumbai  18.85 Lakh*
# 2252           First Owner     Mumbai  18.85 Lakh*
# 2253           First Owner     Mumbai   19.5 Lakh*
# 2254           First Owner     Mumbai     19 Lakh*
# 2255           First Owner     Mumbai     14 Lakh*
# 2256           First Owner     Mumbai   6.25 Lakh*
# 2257           First Owner     Mumbai   3.25 Lakh*
# 2258           First Owner     Mumbai   6.45 Lakh*
# 2259           First Owner     Mumbai  18.75 Lakh*
# 2260           First Owner     Mumbai   19.9 Lakh*
# 2261           First Owner     Mumbai   15.5 Lakh*
# 2262           First Owner     Mumbai   9.55 Lakh*
# 2263          Second Owner     Mumbai   3.65 Lakh*
# 2264           First Owner     Mumbai      6 Lakh*
# 2265          Second Owner     Mumbai   5.25 Lakh*
# 2266          Second Owner     Mumbai      5 Lakh*
# 2267          Second Owner     Mumbai      1 Lakh*
# 2268           Third Owner     Mumbai   5.43 Lakh*
# 2269           First Owner     Mumbai     25 Lakh*
# 2270          Second Owner     Mumbai   19.5 Lakh*
# 2271           First Owner     Mumbai  23.99 Lakh*
# 2272          Second Owner     Mumbai   27.5 Lakh*
# 2273          Second Owner     Mumbai   14.5 Lakh*
# 2274           First Owner     Mumbai   38.5 Lakh*
# 2275          Second Owner     Mumbai  18.25 Lakh*
# 2276          Second Owner     Mumbai     12 Lakh*
# 2277          Second Owner     Mumbai     45 Lakh*
# 2278           First Owner     Mumbai  25.49 Lakh*
# 2279           First Owner     Mumbai  24.99 Lakh*
# 2280           First Owner     Mumbai  37.99 Lakh*
# 2281           First Owner     Mumbai     28 Lakh*
# 2282           First Owner     Mumbai    2.5 Lakh*
# 2283           First Owner     Mumbai    2.5 Lakh*
# 2284           First Owner     Mumbai    3.1 Lakh*
# 2285           First Owner     Mumbai    3.7 Lakh*
# 2286          Second Owner     Mumbai    2.2 Lakh*
# 2287           First Owner     Mumbai    3.4 Lakh*
# 2288           First Owner     Mumbai    3.4 Lakh*
# 2289           First Owner     Mumbai   2.39 Lakh*
# 2290           First Owner     Mumbai   2.49 Lakh*
# 2291          Second Owner     Mumbai   1.75 Lakh*
# 2292           First Owner     Mumbai   2.45 Lakh*
# 2293           First Owner     Mumbai   6.45 Lakh*
# 2294           First Owner     Mumbai   3.75 Lakh*
# 2295           First Owner     Mumbai   1.85 Lakh*
# 2296           First Owner     Mumbai   4.75 Lakh*
# 2297           First Owner     Mumbai   6.15 Lakh*
# 2298          Second Owner     Mumbai   1.68 Lakh*
# 2299           First Owner     Mumbai   1.65 Lakh*
# 2300          Second Owner     Mumbai      3 Lakh*
# 2301          Second Owner     Mumbai    1.5 Lakh*
# 2302           Third Owner     Mumbai    1.1 Lakh*
# 2303           First Owner     Mumbai  14.25 Lakh*
# 2304           First Owner     Mumbai   15.9 Lakh*
# 2305           First Owner     Mumbai     19 Lakh*
# 2306           First Owner     Mumbai   15.6 Lakh*
# 2307           First Owner     Mumbai   48.5 Lakh*
# 2308           First Owner     Mumbai   23.5 Lakh*
# 2309           First Owner     Mumbai     50 Lakh*
# 2310           First Owner     Mumbai     49 Lakh*
# 2311          Second Owner     Mumbai  18.75 Lakh*
# 2312           First Owner     Mumbai   18.1 Lakh*
# 2313           First Owner     Mumbai  37.75 Lakh*
# 2314          Second Owner     Mumbai     18 Lakh*
# 2315           First Owner     Mumbai     38 Lakh*
# 2316          Second Owner     Mumbai     13 Lakh*
# 2317          Second Owner     Mumbai   47.5 Lakh*
# 2318           First Owner     Mumbai     25 Lakh*
# 2319           First Owner     Mumbai  16.11 Lakh*
# 2320           First Owner     Mumbai     16 Lakh*
# 2321           First Owner     Mumbai     26 Lakh*
# 2322          Second Owner     Mumbai     51 Lakh*
# 2323           First Owner     Mumbai   41.5 Lakh*
# 2324           Third Owner     Mumbai   31.5 Lakh*
# 2325          Second Owner     Mumbai     52 Lakh*
# 2326           First Owner     Mumbai     45 Lakh*
# 2327          Second Owner     Mumbai     39 Lakh*
# 2328           First Owner     Mumbai     49 Lakh*
# 2329           First Owner     Mumbai  16.85 Lakh*
# 2330           First Owner     Mumbai     18 Lakh*
# 2331           First Owner     Mumbai  20.25 Lakh*
# 2332           First Owner     Mumbai  18.75 Lakh*
# 2333           First Owner     Mumbai   19.4 Lakh*
# 2334           Third Owner     Mumbai   1.73 Lakh*
# 2335          Second Owner     Mumbai   1.26 Lakh*
# 2336           Third Owner     Mumbai   1.05 Lakh*
# 2337          Second Owner     Mumbai   1.35 Lakh*
# 2338          Second Owner     Mumbai     76 Lakh*
# 2339           First Owner     Mumbai     75 Lakh*
# 2340          Second Owner     Mumbai   2.25 Lakh*
# 2341           First Owner     Mumbai   5.88 Lakh*
# 2342           First Owner     Mumbai   22.5 Lakh*
# 2343          Second Owner     Mumbai   14.5 Lakh*
# 2344           First Owner     Mumbai     1.35 Cr*
# 2345           First Owner     Mumbai      2 Lakh*
# 2346           First Owner     Mumbai    4.5 Lakh*
# 2347           First Owner     Mumbai    6.5 Lakh*
# 2348             1st Owner      Noida     5,42,500
# 2349             1st Owner      Noida     4,32,000
# 2350             1st Owner      Noida     5,93,500
# 2351             1st Owner      Noida     4,75,000
# 2352             1st Owner      Noida     7,02,500
# 2353             1st Owner      Noida     5,42,500
# 2354             1st Owner      Noida     5,78,500
# 2355             1st Owner      Noida     5,51,000
# 2356             2nd Owner      Noida     6,02,000
# 2357             1st Owner      Noida     4,87,500
# 2358             1st Owner      Noida     6,19,500
# 2359             1st Owner      Noida     4,77,000
# 2360             1st Owner      Noida     6,35,000
# 2361             1st Owner      Noida     6,40,000
# 2362             1st Owner      Noida     3,52,000
# 2363             1st Owner      Noida     3,32,000
# 2364             1st Owner      Noida     5,64,500
# 2365             1st Owner      Noida     5,76,500
# 2366             1st Owner      Noida     6,08,000
# 2367             1st Owner      Noida     6,34,500
# 2368             1st Owner      Noida     6,55,500
# 2369             1st Owner      Noida     5,17,408
# 2370             1st Owner      Noida     3,66,500
# 2371             1st Owner      Noida     5,03,000
# 2372             1st Owner      Noida     3,69,500
# 2373             2nd Owner      Noida     3,39,000
# 2374             2nd Owner      Noida     3,56,500
# 2375             1st Owner      Noida     4,94,500
# 2376             1st Owner      Noida     4,89,500
# 2377             1st Owner      Noida    10,17,500
# 2378             1st Owner      Noida     6,68,000
# 2379             1st Owner      Noida     4,28,500
# 2380             1st Owner      Noida     5,41,000
# 2381             1st Owner      Noida     3,13,500
# 2382             2nd Owner      Noida     3,70,465
# 2383             2nd Owner      Noida     2,27,500
# 2384             1st Owner      Noida     2,22,500
# 2385             2nd Owner      Noida     2,08,000
# 2386             2nd Owner      Noida     5,31,846
# 2387             2nd Owner      Noida     4,80,500
# 2388             1st Owner      Noida     3,88,500
# 2389             2nd Owner      Noida     2,97,500
# 2390             1st Owner      Noida     3,04,500
# 2391             1st Owner      Noida     3,94,500
# 2392             1st Owner      Noida     5,38,000
# 2393             2nd Owner      Noida     2,15,500
# 2394             1st Owner      Noida     3,28,000
# 2395             1st Owner      Noida     5,96,463
# 2396             1st Owner      Noida     7,38,321
# 2397          Second Owner      Noida   9.75 Lakh*
# 2398           Third Owner      Noida  15.75 Lakh*
# 2399           Third Owner      Noida  13.25 Lakh*
# 2400           Third Owner      Noida    7.5 Lakh*
# 2401           First Owner      Noida      7 Lakh*
# 2402          Second Owner      Noida     22 Lakh*
# 2403           First Owner      Noida     82 Lakh*
# 2404           First Owner      Noida     75 Lakh*
# 2405           First Owner      Noida      75,000*
# 2406           First Owner      Noida      6 Lakh*
# 2407           First Owner      Noida    1.6 Lakh*
# 2408          Second Owner      Noida   1.45 Lakh*
# 2409           First Owner      Noida      90,000*
# 2410          Second Owner      Noida    8.2 Lakh*
# 2411           First Owner      Noida   16.2 Lakh*
# 2412  Fourth & Above Owner      Noida     11 Lakh*
# 2413          Second Owner      Noida   24.5 Lakh*
# 2414           First Owner      Noida    4.7 Lakh*
# 2415           First Owner      Noida   4.85 Lakh*
# 2416           First Owner      Noida  24.49 Lakh*
# 2417           First Owner      Noida   5.75 Lakh*
# 2418           First Owner      Noida   2.55 Lakh*
# 2419           First Owner      Noida   4.15 Lakh*
# 2420          Second Owner      Noida   2.85 Lakh*
# 2421           Third Owner      Noida    9.5 Lakh*
# 2422           First Owner      Noida   3.75 Lakh*
# 2423          Second Owner      Noida     12 Lakh*
# 2424          Second Owner      Noida   6.25 Lakh*
# 2425           First Owner      Noida  17.75 Lakh*
# 2426             1st Owner      Noida     2,70,000
# 2427           First Owner      Noida  18.75 Lakh*
# 2428             1st Owner       Pune     3,90,000
# 2429             1st Owner       Pune     3,98,000
# 2430             1st Owner       Pune     4,42,000
# 2431             1st Owner       Pune     3,79,500
# 2432             1st Owner       Pune     5,91,500
# 2433             2nd Owner       Pune     8,01,500
# 2434             1st Owner       Pune     4,23,500
# 2435             1st Owner       Pune     4,57,500
# 2436             1st Owner       Pune     3,67,000
# 2437             1st Owner       Pune     4,77,000
# 2438             1st Owner       Pune     5,80,500
# 2439             1st Owner       Pune     4,56,000
# 2440             1st Owner       Pune     5,43,000
# 2441             1st Owner       Pune     4,20,500
# 2442           First Owner       Pune   5.95 Lakh*
# 2443           First Owner       Pune   6.15 Lakh*
# 2444           First Owner       Pune   8.16 Lakh*
# 2445           First Owner       Pune   3.39 Lakh*
# 2446           First Owner       Pune    5.4 Lakh*
# 2447           First Owner       Pune    9.2 Lakh*
# 2448             2nd Owner       Pune     4,69,500
# 2449             1st Owner       Pune     6,04,500
# 2450             1st Owner       Pune     5,75,000
# 2451             1st Owner       Pune     5,70,500
# 2452             1st Owner       Pune     5,97,500
# 2453             1st Owner       Pune     4,69,000
# 2454             1st Owner       Pune     5,58,000
# 2455             1st Owner       Pune     5,33,500
# 2456             1st Owner       Pune     8,22,500
# 2457             1st Owner       Pune     6,49,000
# 2458             2nd Owner       Pune     5,65,000
# 2459             2nd Owner       Pune     5,61,500
# 2460             1st Owner       Pune     6,12,000
# 2461             1st Owner       Pune     9,86,000
# 2462             1st Owner       Pune     4,45,000
# 2463             2nd Owner       Pune     2,20,500
# 2464           First Owner       Pune     12 Lakh*
# 2465           First Owner       Pune   7.87 Lakh*
# 2466           First Owner       Pune   9.95 Lakh*
# 2467           First Owner       Pune   4.45 Lakh*
# 2468             1st Owner       Pune     6,51,500
# 2469             1st Owner       Pune     6,38,000
# 2470             1st Owner       Pune     7,53,000
# 2471             2nd Owner       Pune     4,08,000
# 2472           First Owner       Pune    6.5 Lakh*
# 2473           First Owner       Pune    5.5 Lakh*
# 2474           First Owner       Pune   6.25 Lakh*
# 2475           First Owner       Pune   3.75 Lakh*
# 2476           First Owner       Pune   4.85 Lakh*
# 2477           First Owner       Pune   13.5 Lakh*
# 2478           First Owner       Pune   4.35 Lakh*
# 2479           First Owner       Pune    4.1 Lakh*
# 2480           First Owner       Pune    5.5 Lakh*
# 2481          Second Owner       Pune   3.49 Lakh*
# 2482           First Owner       Pune    9.5 Lakh*
# 2483           First Owner       Pune   4.91 Lakh*
# 2484           First Owner       Pune   7.75 Lakh*
# 2485           First Owner       Pune   5.25 Lakh*
# 2486           First Owner       Pune    3.6 Lakh*
# 2487           First Owner       Pune   5.99 Lakh*
# 2488             2nd Owner       Pune     5,59,500
# 2489             1st Owner       Pune     7,26,000
# 2490             1st Owner       Pune     3,28,500
# 2491           First Owner       Pune   6.25 Lakh*
# 2492          Second Owner       Pune    4.5 Lakh*
# 2493           First Owner       Pune    6.5 Lakh*
# 2494           First Owner       Pune    3.5 Lakh*
# 2495           First Owner       Pune   7.25 Lakh*
# 2496           First Owner       Pune      8 Lakh*
# 2497          Second Owner       Pune   3.75 Lakh*
# 2498          Second Owner       Pune   3.75 Lakh*
# 2499           First Owner       Pune      5 Lakh*
# 2500           First Owner       Pune   3.41 Lakh*
# 2501           First Owner       Pune    5.6 Lakh*
# 2502          Second Owner       Pune   2.75 Lakh*
# 2503          Second Owner       Pune   5.25 Lakh*
# 2504           First Owner       Pune   3.65 Lakh*
# 2505           First Owner       Pune    8.5 Lakh*
# 2506           First Owner       Pune   2.95 Lakh*
# 2507           First Owner       Pune   7.25 Lakh*
# 2508             1st Owner       Pune    17,49,500
# 2509           First Owner       Pune   2.99 Lakh*
# 2510          Second Owner       Pune   5.95 Lakh*
# 2511           First Owner       Pune     15 Lakh*
# 2512          Second Owner       Pune    9.5 Lakh*
# 2513           First Owner       Pune  18.41 Lakh*
# 2514           First Owner       Pune   4.65 Lakh*
# 2515           First Owner       Pune     11 Lakh*
# 2516          Second Owner       Pune      5 Lakh*
# 2517          Second Owner       Pune      7 Lakh*
# 2518           First Owner       Pune     10 Lakh*
# 2519           First Owner       Pune     11 Lakh*
# 2520          Second Owner       Pune   13.5 Lakh*
# 2521           First Owner       Pune  15.75 Lakh*
# 2522           First Owner       Pune     11 Lakh*
# 2523          Second Owner       Pune   2.25 Lakh*
# 2524          Second Owner       Pune   13.5 Lakh*
# 2525          Second Owner       Pune   4.35 Lakh*
# 2526          Second Owner       Pune   7.25 Lakh*
# 2527          Second Owner       Pune    4.5 Lakh*
# 2528           First Owner       Pune    3.3 Lakh*
# 2529           First Owner       Pune   4.11 Lakh*

# %%
data_frame.to_csv('cardekho_data_part2.csv')
